# %%
import pandas as pd
df=pd.read_csv("loan_approval_dataset.csv")
df
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 0                1   56   21920           639       452748         72
# 1                2   69  126121           655       257134         60
# 2                3   46   96872           467       226437         72
# 3                4   32  101132           751       310480         12
# 4                5   60   22093           404        13070         12
# ...            ...  ...     ...           ...          ...        ...
# 4995          4996   24  169594           755       299944         48
# 4996          4997   66  162728           829        15886         24
# 4997          4998   26  166965           468       477830         48
# 4998          4999   53   36493           442       205981         60
# 4999          5000   36  154704           336       183308         36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# ...

# %%
#pandas are case sensitive.

# %% [markdown]
# ## 1. Handling Missing Values

# %% [markdown]
# ### Check for missing values

# %%
df.isnull().sum()
# Out:
# Applicant_ID            0
# Age                     0
# Income                  0
# Credit_Score            0
# Loan_Amount             0
# Loan_Term               0
# Interest_Rate           0
# Employment_Status       0
# Debt_to_Income_Ratio    0
# Marital_Status          0
# Number_of_Dependents    0
# Property_Ownership      0
# Loan_Purpose            0
# Previous_Defaults       0
# dtype: int64

# %% [markdown]
# ### Currently no missing value if have Drop rows with missing values

# %%
df.dropna(inplace=True)
df
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 0                1   56   21920           639       452748         72
# 1                2   69  126121           655       257134         60
# 2                3   46   96872           467       226437         72
# 3                4   32  101132           751       310480         12
# 4                5   60   22093           404        13070         12
# ...            ...  ...     ...           ...          ...        ...
# 4995          4996   24  169594           755       299944         48
# 4996          4997   66  162728           829        15886         24
# 4997          4998   26  166965           468       477830         48
# 4998          4999   53   36493           442       205981         60
# 4999          5000   36  154704           336       183308         36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# ...

# %% [markdown]
# ### Fill missing values with mean/median/mode

# %%
df['Income'] = df['Income'].fillna(df['Income'].mean())
df['Employment_Status'] = df['Employment_Status'].fillna(df['Employment_Status'].mode().iloc[0])
df
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 0                1   56   21920           639       452748         72
# 1                2   69  126121           655       257134         60
# 2                3   46   96872           467       226437         72
# 3                4   32  101132           751       310480         12
# 4                5   60   22093           404        13070         12
# ...            ...  ...     ...           ...          ...        ...
# 4995          4996   24  169594           755       299944         48
# 4996          4997   66  162728           829        15886         24
# 4997          4998   26  166965           468       477830         48
# 4998          4999   53   36493           442       205981         60
# 4999          5000   36  154704           336       183308         36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# ...

# %% [markdown]
# ## 2 Removing Duplicates

# %% [markdown]
# ### Check for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Drop duplicates (if any duplicate raised, then proceed to drop duplicates)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 0                1   56   21920           639       452748         72
# 1                2   69  126121           655       257134         60
# 2                3   46   96872           467       226437         72
# 3                4   32  101132           751       310480         12
# 4                5   60   22093           404        13070         12
# ...            ...  ...     ...           ...          ...        ...
# 4995          4996   24  169594           755       299944         48
# 4996          4997   66  162728           829        15886         24
# 4997          4998   26  166965           468       477830         48
# 4998          4999   53   36493           442       205981         60
# 4999          5000   36  154704           336       183308         36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# ...

# %% [markdown]
# ## 3. Data Type Corrections

# %% [markdown]
# ### Check data types

# %%
df.dtypes
# Out:
# Applicant_ID              int64
# Age                       int64
# Income                    int64
# Credit_Score              int64
# Loan_Amount               int64
# Loan_Term                 int64
# Interest_Rate           float64
# Employment_Status        object
# Debt_to_Income_Ratio    float64
# Marital_Status           object
# Number_of_Dependents      int64
# Property_Ownership       object
# Loan_Purpose             object
# Previous_Defaults         int64
# dtype: object

# %% [markdown]
# ### Convert columns to correct types

# %%
# Convert Loan_Term to integer
df['Loan_Term'] = df['Loan_Term'].astype(int)

# Convert Interest_Rate to numeric, set invalid values to NaN()int or float)(errors='coerce'
#If a value cannot be converted to a number (like a string "N/A" or "unknown"), it will be turned into NaN (Not a Number) instead of raising an error.)
df['Interest_Rate'] = pd.to_numeric(df['Interest_Rate'], errors='coerce')

# Example: Convert integer column to string
# df['Loan_ID'] = df['Loan_ID'].astype(str)

df
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 0                1   56   21920           639       452748         72
# 1                2   69  126121           655       257134         60
# 2                3   46   96872           467       226437         72
# 3                4   32  101132           751       310480         12
# 4                5   60   22093           404        13070         12
# ...            ...  ...     ...           ...          ...        ...
# 4995          4996   24  169594           755       299944         48
# 4996          4997   66  162728           829        15886         24
# 4997          4998   26  166965           468       477830         48
# 4998          4999   53   36493           442       205981         60
# 4999          5000   36  154704           336       183308         36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# ...

# %% [markdown]
# ## 4 IQR (Interquartile Range)

# %%
ex:
[100, 120, 130, 150, 160, 170, 180, 200, 1000]
In this case, 1000 is way above the upper bound, so it's considered an outlier and removed.

This helps improve the accuracy of statistical analysis and machine learning models.

# %%
#IQR detects outliers
#below the lower bound or above the upper bound is considered an outlier. effective even for skewed data.
#(Skewness measures how asymmetrical a data distribution is compared to a perfectly symmetrical (normal) distribution.)
Q1 = df['Loan_Amount'].quantile(0.25)
Q3 = df['Loan_Amount'].quantile(0.75)
IQR = Q3 - Q1
df = df[(df['Loan_Amount'] >= Q1 - 1.5*IQR) & (df['Loan_Amount'] <= Q3 + 1.5*IQR)]
df
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 0                1   56   21920           639       452748         72
# 1                2   69  126121           655       257134         60
# 2                3   46   96872           467       226437         72
# 3                4   32  101132           751       310480         12
# 4                5   60   22093           404        13070         12
# ...            ...  ...     ...           ...          ...        ...
# 4995          4996   24  169594           755       299944         48
# 4996          4997   66  162728           829        15886         24
# 4997          4998   26  166965           468       477830         48
# 4998          4999   53   36493           442       205981         60
# 4999          5000   36  154704           336       183308         36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# ...

# %% [markdown]
# ## 5 Renaming Columns for Consistency

# %%
# df.columns = df.columns.str.lower().str.replace(' ', '_')
df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 0                1   56   21920           639       452748         72
# 1                2   69  126121           655       257134         60
# 2                3   46   96872           467       226437         72
# 3                4   32  101132           751       310480         12
# 4                5   60   22093           404        13070         12
# ...            ...  ...     ...           ...          ...        ...
# 4995          4996   24  169594           755       299944         48
# 4996          4997   66  162728           829        15886         24
# 4997          4998   26  166965           468       477830         48
# 4998          4999   53   36493           442       205981         60
# 4999          5000   36  154704           336       183308         36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# ...

# %% [markdown]
# ## 6 Basic Attributes in pandas

# %%
df.columns
# Out:
# Index(['Applicant_ID', 'Age', 'Income', 'Credit_Score', 'Loan_Amount',
#        'Loan_Term', 'Interest_Rate', 'Employment_Status',
#        'Debt_to_Income_Ratio', 'Marital_Status', 'Number_of_Dependents',
#        'Property_Ownership', 'Loan_Purpose', 'Previous_Defaults'],
#       dtype='object')

# %%
df.shape
# Out:
# (5000, 14)

# %%
df.dtypes
# Out:
# Applicant_ID              int64
# Age                       int64
# Income                    int64
# Credit_Score              int64
# Loan_Amount               int64
# Loan_Term                 int32
# Interest_Rate           float64
# Employment_Status        object
# Debt_to_Income_Ratio    float64
# Marital_Status           object
# Number_of_Dependents      int64
# Property_Ownership       object
# Loan_Purpose             object
# Previous_Defaults         int64
# dtype: object

# %% [markdown]
# ## 7 Basic method in pandas

# %%
df.describe()
# Out:
#        Applicant_ID          Age         Income  Credit_Score   Loan_Amount  \
# count   5000.000000  5000.000000    5000.000000   5000.000000    5000.00000
# mean    2500.500000    43.584600  110220.247000    574.183200  252118.47900
# std     1443.520003    14.919094   52075.384023    160.437715  142580.00452
# min        1.000000    18.000000   20028.000000    300.000000    5050.00000
# 25%     1250.750000    31.000000   64751.000000    434.750000  129940.25000
# 50%     2500.500000    43.000000  110180.500000    573.000000  250846.50000
# 75%     3750.250000    56.000000  155749.750000    715.000000  378021.75000
# max     5000.000000    69.000000  199992.000000    849.000000  499651.00000
#
#          Loan_Term  Interest_Rate  Debt_to_Income_Ratio  Number_of_Dependents  \
# count  5000.000000    5000.000000           5000.000000           5000.000000
# mean     41.769600       8.873018             27.177244              2.010200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Applicant_ID          5000 non-null   int64
#  1   Age                   5000 non-null   int64
#  2   Income                5000 non-null   int64
#  3   Credit_Score          5000 non-null   int64
#  4   Loan_Amount           5000 non-null   int64
#  5   Loan_Term             5000 non-null   int32
#  6   Interest_Rate         5000 non-null   float64
#  7   Employment_Status     5000 non-null   object
#  8   Debt_to_Income_Ratio  5000 non-null   float64
#  9   Marital_Status        5000 non-null   object
#  10  Number_of_Dependents  5000 non-null   int64
#  11  Property_Ownership    5000 non-null   object
#  12  Loan_Purpose          5000 non-null   object
#  13  Previous_Defaults     5000 non-null   int64
# dtypes: float64(2), int32(1), int64(7), object(4)
# ...

# %%
df.head()
# Out:
#    Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 0             1   56   21920           639       452748         72
# 1             2   69  126121           655       257134         60
# 2             3   46   96872           467       226437         72
# 3             4   32  101132           751       310480         12
# 4             5   60   22093           404        13070         12
#
#    Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# 0           4.53        Unemployed                 43.35        Married
# 1           5.38        Unemployed                 10.42       Divorced
# 2           3.46     Self-Employed                 45.39       Divorced
# 3          14.00        Unemployed                  8.58         Single
# 4           9.13     Self-Employed                 20.70       Divorced
#
#    Number_of_Dependents Property_Ownership Loan_Purpose  Previous_Defaults
# ...

# %%
df.tail()
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 4995          4996   24  169594           755       299944         48
# 4996          4997   66  162728           829        15886         24
# 4997          4998   26  166965           468       477830         48
# 4998          4999   53   36493           442       205981         60
# 4999          5000   36  154704           336       183308         36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# 4995           9.42     Self-Employed                 40.83        Married
# 4996           3.47        Unemployed                 34.88        Married
# 4997           9.08     Self-Employed                 37.84        Married
# 4998          12.39     Self-Employed                 18.83        Widowed
# 4999           3.51        Unemployed                 16.85        Widowed
#
#       Number_of_Dependents Property_Ownership Loan_Purpose  Previous_Defaults
# ...

# %%
df.sum()
# Out:
# Applicant_ID                                                     12502500
# Age                                                                217923
# Income                                                          551101235
# Credit_Score                                                      2870916
# Loan_Amount                                                    1260592395
# Loan_Term                                                          208848
# Interest_Rate                                                    44365.09
# Employment_Status       UnemployedUnemployedSelf-EmployedUnemployedSel...
# Debt_to_Income_Ratio                                            135886.22
# Marital_Status          MarriedDivorcedDivorcedSingleDivorcedSingleMar...
# Number_of_Dependents                                                10051
# Property_Ownership      MortgageMortgageMortgageMortgageMortgageOwnRen...
# Loan_Purpose            BusinessEducationCarBusinessHomeEducationPerso...
# ...

# %% [markdown]
# ## 8.Aggrigations

# %%
df
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 0                1   56   21920           639       452748         72
# 1                2   69  126121           655       257134         60
# 2                3   46   96872           467       226437         72
# 3                4   32  101132           751       310480         12
# 4                5   60   22093           404        13070         12
# ...            ...  ...     ...           ...          ...        ...
# 4995          4996   24  169594           755       299944         48
# 4996          4997   66  162728           829        15886         24
# 4997          4998   26  166965           468       477830         48
# 4998          4999   53   36493           442       205981         60
# 4999          5000   36  154704           336       183308         36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# ...

# %%
# Count customers
total_customers = df['Applicant_ID'].nunique()
total_customers
# Out:
# 5000

# %%
df.nunique()
# Out:
# Applicant_ID            5000
# Age                       52
# Income                  4924
# Credit_Score             550
# Loan_Amount             4984
# Loan_Term                  6
# Interest_Rate           1236
# Employment_Status          3
# Debt_to_Income_Ratio    2965
# Marital_Status             4
# Number_of_Dependents       5
# Property_Ownership         3
# Loan_Purpose               5
# Previous_Defaults          2
# dtype: int64

# %% [markdown]
# ### What is the most common employment status among applicants?

# %%
df['Employment_Status'].value_counts()
# Out:
# Employment_Status
# Self-Employed    1723
# Employed         1666
# Unemployed       1611
# Name: count, dtype: int64

# %% [markdown]
# ### What is the age range of applicants?

# %%
df['Age'].min(), df['Age'].max()
# Out:
# (18, 69)

# %% [markdown]
# ### Create a new column for monthly loan payment estimate.

# %%
df['Monthly_Payment'] = (df['Loan_Amount'] / df['Loan_Term']).round(2)
df
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 0                1   56   21920           639       452748         72
# 1                2   69  126121           655       257134         60
# 2                3   46   96872           467       226437         72
# 3                4   32  101132           751       310480         12
# 4                5   60   22093           404        13070         12
# ...            ...  ...     ...           ...          ...        ...
# 4995          4996   24  169594           755       299944         48
# 4996          4997   66  162728           829        15886         24
# 4997          4998   26  166965           468       477830         48
# 4998          4999   53   36493           442       205981         60
# 4999          5000   36  154704           336       183308         36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# ...

# %% [markdown]
# ### Create a binary feature: High Credit Score (above 700).

# %%
df['High_Credit_Score'] = df['Credit_Score'] > 700
df
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 0                1   56   21920           639       452748         72
# 1                2   69  126121           655       257134         60
# 2                3   46   96872           467       226437         72
# 3                4   32  101132           751       310480         12
# 4                5   60   22093           404        13070         12
# ...            ...  ...     ...           ...          ...        ...
# 4995          4996   24  169594           755       299944         48
# 4996          4997   66  162728           829        15886         24
# 4997          4998   26  166965           468       477830         48
# 4998          4999   53   36493           442       205981         60
# 4999          5000   36  154704           336       183308         36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# ...

# %% [markdown]
# ### Bucket income into categories (Low, Medium, High).

# %%
df['Income_Level'] = pd.cut(df['Income'], bins=[0,50000,100000,200000], labels=['Low','Medium','High'])
df
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 0                1   56   21920           639       452748         72
# 1                2   69  126121           655       257134         60
# 2                3   46   96872           467       226437         72
# 3                4   32  101132           751       310480         12
# 4                5   60   22093           404        13070         12
# ...            ...  ...     ...           ...          ...        ...
# 4995          4996   24  169594           755       299944         48
# 4996          4997   66  162728           829        15886         24
# 4997          4998   26  166965           468       477830         48
# 4998          4999   53   36493           442       205981         60
# 4999          5000   36  154704           336       183308         36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# ...

# %% [markdown]
# ## 9 Grouping in pandas

# %% [markdown]
# ### Average of customer per marial status there credit score

# %%
df.groupby('Marital_Status')['Credit_Score'].mean().reset_index().round(2)
# Out:
#   Marital_Status  Credit_Score
# 0       Divorced        579.05
# 1        Married        575.26
# 2         Single        568.50
# 3        Widowed        573.92

# %% [markdown]
# ### Standard Deviation of Income by Marital Status

# %%
df.groupby('Marital_Status')['Income'].std()
# Out:
# Marital_Status
# Divorced    52322.557864
# Married     51872.325387
# Single      51483.758951
# Widowed     52656.329173
# Name: Income, dtype: float64

# %% [markdown]
# ### Maximum Interest Rate by Loan Purpose

# %%
df.groupby('Loan_Purpose')['Interest_Rate'].max()
# Out:
# Loan_Purpose
# Business     15.00
# Car          14.98
# Education    14.98
# Home         15.00
# Personal     15.00
# Name: Interest_Rate, dtype: float64

# %% [markdown]
# ### Slice specific rows and columns using iloc

# %%
df.iloc[5:15, [1, 2, 4, 7]]  # Age, Income, Loan_Amount, Employment_Status (select for positions)
# Out:
#     Age  Income  Loan_Amount Employment_Status
# 5    25   32905         6320        Unemployed
# 6    38  141759       356187     Self-Employed
# 7    56  175423       306065          Employed
# 8    36   50981        11589     Self-Employed
# 9    40   93903       462625          Employed
# 10   28   90821       360139     Self-Employed
# 11   28  129200        20589     Self-Employed
# 12   41  102289        41375          Employed
# 13   53  136506        48085     Self-Employed
# 14   57   98513        65840     Self-Employed

# %%
#basic of iocs
# loc selects data by labels (row/column names).

# iloc selects data by integer positions (row/column index numbers).

# %%
df.iloc[1,1]
# Out:
# 69

# %%
df.loc[0,'Number_of_Dependents']
# Out:
# 2

# %%
### Select top 10 applicants by income

# %%
df.sort_values('Income', ascending=False).iloc[:10]
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 707            708   48  199992           469       352364         12
# 1340          1341   38  199971           661        59391         60
# 4041          4042   24  199965           372       297637         36
# 4812          4813   36  199949           499       282972         48
# 1723          1724   32  199921           717       291801         60
# 2331          2332   66  199893           659       431409         48
# 3259          3260   67  199845           446       204933         24
# 1845          1846   53  199736           682       103171         12
# 3516          3517   23  199704           544       427701         48
# 988            989   31  199689           764        99242         60
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# 707           12.70     Self-Employed                 33.71         Single
# ...

# %%
### upadate age of applicant id 708 as 50

# %%
df.loc[df["Applicant_ID"]==1,"Age"]=50
df
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 0                1   50   21920           639       452748         72
# 1                2   69  126121           655       257134         60
# 2                3   46   96872           467       226437         72
# 3                4   32  101132           751       310480         12
# 4                5   60   22093           404        13070         12
# ...            ...  ...     ...           ...          ...        ...
# 4995          4996   24  169594           755       299944         48
# 4996          4997   66  162728           829        15886         24
# 4997          4998   26  166965           468       477830         48
# 4998          4999   53   36493           442       205981         60
# 4999          5000   36  154704           336       183308         36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# ...

# %% [markdown]
# ### change the column name your wish

# %%
# Parentheses () are used for function calls or grouping expressions, while curly braces {} define dictionaries, sets, or formatted string placeholders
# in Python.
df.rename(columns={'Loan_Term': 'Loan_Tenure'}, inplace=True)
df
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Tenure  \
# 0                1   50   21920           639       452748           72
# 1                2   69  126121           655       257134           60
# 2                3   46   96872           467       226437           72
# 3                4   32  101132           751       310480           12
# 4                5   60   22093           404        13070           12
# ...            ...  ...     ...           ...          ...          ...
# 4995          4996   24  169594           755       299944           48
# 4996          4997   66  162728           829        15886           24
# 4997          4998   26  166965           468       477830           48
# 4998          4999   53   36493           442       205981           60
# 4999          5000   36  154704           336       183308           36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# ...

# %% [markdown]
# ### 10.EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### histogram

# %% [markdown]
# ### Age vs Monthly Paymen --line plot

# %%
df.sort_values('Age').plot(x='Age', y='Monthly_Payment', kind='line', title='Age vs Monthly Payment')
plt.ylabel('Monthly Payment')
plt.show()

# %% [markdown]
# ### Scatter Plot — Income vs Credit Score

# %%
df.plot(kind='scatter', x='Income', y='Credit_Score', title='Income vs Credit Score')
plt.show()

# %% [markdown]
# ### Bar Plot — Average Loan Amount by Employment Status

# %%
df['Debt_to_Income_Ratio'].plot(kind='hist', bins=20, title='Debt-to-Income Ratio Distribution',edgecolour="black", palette='viridis')
plt.xlabel('Ratio')
plt.show()

# %% [markdown]
# ### Box Plot — Loan Amount by Property Ownership

# %%
df.boxplot(column='Loan_Amount', by='Property_Ownership')
plt.title('Loan Amount by Property Ownership')
plt.suptitle('')
plt.ylabel('Loan Amount')
plt.show()

# %%
# df['Credit_History'] = np.random.choice([1, 0], size=len(df), p=[0.8, 0.2])
# df
df['Loan_Status'] = np.random.choice(['Y', 'N'], size=len(df), p=[0.7, 0.3])
df
# Out:
#       Applicant_ID  Age  Income  Credit_Score  Loan_Amount  Loan_Term  \
# 0                1   56   21920           639       452748         72
# 1                2   69  126121           655       257134         60
# 2                3   46   96872           467       226437         72
# 3                4   32  101132           751       310480         12
# 4                5   60   22093           404        13070         12
# ...            ...  ...     ...           ...          ...        ...
# 4995          4996   24  169594           755       299944         48
# 4996          4997   66  162728           829        15886         24
# 4997          4998   26  166965           468       477830         48
# 4998          4999   53   36493           442       205981         60
# 4999          5000   36  154704           336       183308         36
#
#       Interest_Rate Employment_Status  Debt_to_Income_Ratio Marital_Status  \
# ...

# %% [markdown]
# # STATISTICS

# %% [markdown]
# ## DESCRIPTIVE STATISTICS

# %% [markdown]
# ### 1. Measures of Central Tendency

# %% [markdown]
# #### Mean (average):

# %%
df['Loan_Amount'].mean()
# Out:
# 252118.479

# %% [markdown]
# #### Median (middle value):

# %%
df['Loan_Amount'].median()
# Out:
# 250846.5

# %% [markdown]
# #### Mode (most frequent value):

# %%
df['Loan_Amount'].mode()[0]
# Out:
# 6607

# %% [markdown]
# ### 2. Measures of Dispersion

# %% [markdown]
# #### Range:

# %%
df['Loan_Amount'].max() - df['Loan_Amount'].min()
# Out:
# 494601

# %% [markdown]
# #### Variance

# %%
df['Loan_Amount'].var()
# Out:
# 20329057688.84616

# %% [markdown]
# #### Standard Deviation (SD)

# %%
df['Loan_Amount'].std()
# Out:
# 142580.00451972976

# %% [markdown]
# #### Inter Quartile Range(IQR)

# %%
Q3 = df['Loan_Amount'].quantile(0.75)
Q1 = df['Loan_Amount'].quantile(0.25)
IQR = Q3 - Q1
IQR
# Example output: 80
# Out:
# 248081.5

# %% [markdown]
# ### INFERENTIAL STATISTICS

# %% [markdown]
# ### 3. Probability Theory

# %% [markdown]
# #### Probability of a loan being approved

# %%
prob_approved = (df['Loan_Status'] == 'Y').mean()
prob_approved
# Out:
# 0.7078

# %% [markdown]
# #### Conditional Probability: Probability of approval given Credit_History = 1

# %%
prob_cond = df[df['Credit_History'] == 1]['Loan_Status'].value_counts(normalize=True)['Y']
prob_cond
# Out:
# 0.705379587732529

# %% [markdown]
# ### 4. Estimation

# %% [markdown]
# #### Point Estimate (mean income):

# %%
df['Income'].mean()
# Out:
# 110220.247

# %% [markdown]
# ### 5. Confidence Intervals

# %% [markdown]
# #### Using a 95% confidence interval for mean Loan_Amount:

# %%
import scipy.stats as stats
import numpy as np

data = df['Loan_Amount'].dropna()
mean = np.mean(data)
std = np.std(data, ddof=1)
n = len(data)
ci = stats.t.interval(0.95, n-1, loc=mean, scale=std/np.sqrt(n))
ci
# Out:
# (248165.47842726315, 256071.47957273683)

# %% [markdown]
# ### 6. Hypothesis Testing

# %% [markdown]
# #### "Is the average Loan_Amount greater than 200?"

# %%
stats.ttest_1samp(df['Loan_Amount'].dropna(), 200)
# Out:
# TtestResult(statistic=124.93565658601975, pvalue=0.0, df=4999)

# %% [markdown]
# ### 7. ANOVA

# %% [markdown]
# #### Example: Compare mean Applicant_Income across Marital_Status

# %%
from scipy.stats import f_oneway

single = df[df['Marital_Status']=='Single']['Income']
married = df[df['Marital_Status']=='Married']['Income']

f_oneway(single, married)
# Out:
# F_onewayResult(statistic=0.38515762927252106, pvalue=0.5349122168301323)

# %% [markdown]
# ### 8. Regression and Correlation

# %% [markdown]
# #### Correlation (relationship between income & loan amount):

# %%
df[['Income','Loan_Amount']].corr()
# Out:
#                Income  Loan_Amount
# Income       1.000000     0.007326
# Loan_Amount  0.007326     1.000000

# %% [markdown]
# #### Simple Linear Regression: Predict Loan_Amount from Applicant_Income

# %%
from sklearn.linear_model import LinearRegression

X = df[['Income']]
y = df['Loan_Amount']
model = LinearRegression()
model.fit(X, y)
model.coef_, model.intercept_
# Out:
# (array([0.0200572]), 249907.76938963242)
